# %% [markdown]
# <a href="https://colab.research.google.com/github/AgunsBaba/Assignment/blob/master/Neural_Net_Kaggle_Satander.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import modules
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import losses
from keras import metrics
from keras import models
from keras import layers

# %%
#import data
df = pd.read_csv('/content/Satander.csv')
df.head()
# Out:
#    ID_code  target    var_0   var_1  ...  var_196  var_197  var_198  var_199
# 0  train_0       0   8.9255 -6.7863  ...   7.8784   8.5635  12.7803  -1.0914
# 1  train_1       0  11.5006 -4.1473  ...   8.1267   8.7889  18.3560   1.9518
# 2  train_2       0   8.6093 -2.7457  ...  -6.5213   8.2675  14.7222   0.3965
# 3  train_3       0  11.0604 -2.1518  ...  -2.9275  10.2922  17.9697  -8.9996
# 4  train_4       0   9.8369 -1.4834  ...   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
#Make the 'ID_code' column the dataframe index, since the column does not provie any predictive value
df = df.set_index('ID_code')
df.head()
# Out:
#          target    var_0   var_1    var_2  ...  var_196  var_197  var_198  var_199
# ID_code                                    ...
# train_0       0   8.9255 -6.7863  11.9081  ...   7.8784   8.5635  12.7803  -1.0914
# train_1       0  11.5006 -4.1473  13.8588  ...   8.1267   8.7889  18.3560   1.9518
# train_2       0   8.6093 -2.7457  12.0805  ...  -6.5213   8.2675  14.7222   0.3965
# train_3       0  11.0604 -2.1518   8.9522  ...  -2.9275  10.2922  17.9697  -8.9996
# train_4       0   9.8369 -1.4834  12.8746  ...   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 201 columns]

# %%
#split into X and y variables
X = df.drop(columns=['target'])
y = df['target']

# %%
#check class distribution
df['target'].value_counts()
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
#test train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#convert data to numpy arrays so as to be able to feed it into a neural network
my_data = (X_train, X_test, y_train, y_test)
for i in my_data:
  i = i.to_numpy()

# %%
#Data pre-processing
scaler = StandardScaler()

# %%
#scale the data
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
#convert class labels to categorical variables
y_train = to_categorical(y_train, num_classes = 2)
y_test = to_categorical(y_test, num_classes = 2)

# %%
#define model
model = Sequential()

# %%
#instantiate input shape
input_shape = X_train.shape[1]
input_shape
# Out:
# 200

# %%
#define model architecture
model.add(layers.Dense(32, 
                       activation='relu',
                       input_shape=(input_shape,)))
model.add(layers.Dense(16,
                       activation='relu'))
model.add(layers.Dense(16,
                       activation='relu'))
model.add(layers.Dense(2, activation='sigmoid'))

# %%
#compile model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
#fit model
history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=20)
# Out:
# Epoch 1/20
# 4375/4375 [==============================] - 10s 2ms/step - loss: 0.2550 - acc: 0.9065 - val_loss: 0.2421 - val_acc: 0.9107
# Epoch 2/20
# 4375/4375 [==============================] - 10s 2ms/step - loss: 0.2329 - acc: 0.9143 - val_loss: 0.2410 - val_acc: 0.9112
# Epoch 3/20
# 4375/4375 [==============================] - 9s 2ms/step - loss: 0.2291 - acc: 0.9154 - val_loss: 0.2404 - val_acc: 0.9103
# Epoch 4/20
# 4375/4375 [==============================] - 9s 2ms/step - loss: 0.2257 - acc: 0.9162 - val_loss: 0.2427 - val_acc: 0.9105
# Epoch 5/20
# 4375/4375 [==============================] - 9s 2ms/step - loss: 0.2222 - acc: 0.9174 - val_loss: 0.2449 - val_acc: 0.9100
# Epoch 6/20
# 4375/4375 [==============================] - 10s 2ms/step - loss: 0.2191 - acc: 0.9186 - val_loss: 0.2467 - val_acc: 0.9097
# Epoch 7/20
# 4375/4375 [==============================] - 9s 2ms/step - loss: 0.2161 - acc: 0.9192 - val_loss: 0.2488 - val_acc: 0.9091
# Epoch 8/20
# ...

# %%
#import Kaggle test/submission file
df_sub = pd.read_csv('/content/Satander_test.csv')
df_sub.head()
# Out:
#   ID_code    var_0    var_1    var_2  ...  var_196  var_197  var_198  var_199
# 0  test_0  11.0656   7.7798  12.9536  ...   4.3654  10.7200  15.4722  -8.7197
# 1  test_1   8.5304   1.2543  11.3047  ...  -1.4852   9.8714  19.1293 -20.9760
# 2  test_2   5.4827 -10.3581  10.1407  ...  -7.1086   7.0618  19.8956 -23.1794
# 3  test_3   8.5374  -1.3222  12.0220  ...   3.9567   9.2295  13.0168  -4.2108
# 4  test_4  11.7058  -0.1327  14.1295  ...  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %%
#Make the 'ID_code' column the dataframe index, since the column does not provie any predictive value
df_sub = df_sub.set_index('ID_code')
df_sub.head()
# Out:
#            var_0    var_1    var_2   var_3  ...  var_196  var_197  var_198  var_199
# ID_code                                     ...
# test_0   11.0656   7.7798  12.9536  9.4292  ...   4.3654  10.7200  15.4722  -8.7197
# test_1    8.5304   1.2543  11.3047  5.1858  ...  -1.4852   9.8714  19.1293 -20.9760
# test_2    5.4827 -10.3581  10.1407  7.0479  ...  -7.1086   7.0618  19.8956 -23.1794
# test_3    8.5374  -1.3222  12.0220  6.5749  ...   3.9567   9.2295  13.0168  -4.2108
# test_4   11.7058  -0.1327  14.1295  7.7506  ...  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 200 columns]

# %%
#convert data to numpy array to enable our neural net call 'predict' on it
df_array = df_sub.to_numpy()

# %%
#instantiate model prediction
pred = model.predict(df_array)

# %%
#set prediction probability greater than 0.5 to class 1 and everything else to class 0
pred_test = np.where(pred > 0.5, 1, 0)

# %%
#convert predictions to a dataframe
pred_df = pd.DataFrame(pred_test, columns=['target', 'target1'], index=[df_sub.index])
pred_df.head()
# Out:
#          target  target1
# ID_code
# test_0        1        0
# test_1        1        0
# test_2        1        0
# test_3        1        0
# test_4        1        0

# %%
#select first column in the prediction data frame since the first column is the predicted class
final = pred_df.drop(columns='target1')
final.head()
# Out:
#          target
# ID_code
# test_0        1
# test_1        1
# test_2        1
# test_3        1
# test_4        1

# %%
#save prediction as file to be uploaded to Kaggle
final.to_csv('final_nn.csv')

# %% [markdown]
# ![Neural Net.JPG](data:image/jpeg;base64,...)
